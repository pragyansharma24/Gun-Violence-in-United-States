# %% [markdown]
# # Easy access to guns is leading to more gun-related deaths in the United States

# %% [markdown]
# #### Authored By: [Pragyan Sharma](https://github.com/pragyansharma24), [Prerana Patil](https://github.com/preranap1), [Shriya Rao](https://github.com/shriya22), [Sonal Agrawal](https://github.com/agrasonal)

# %% [markdown]
# ![Alt text](https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/Gun_Violence_Analysis_Video.PNG)

# %% [markdown]
# Video Link: https://www.youtube.com/watch?v=yEI9JHFK7A8&feature=youtube

# %% [markdown]
# ## Introduction

# %% [markdown]
# The United States is a unique country when it comes to gun violence. It is one of the few countries where a [citizen's right to bear arms is protected by the constitution](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts). However, for a long time gun violence has been a complex and multi-faceted issue that is deeply rooted in the American culture.
#
# Gun violence could be in any form. A person could witness an act of gun violence themselves, be threatened or injured with a gun or know someone who has experienced such an incident. With such a scenario in mind, a recent [national poll](http://www.surveyusa.com/client/PollReport.aspx?g=4a9eed40-c8b0-419c-ae82-71e1dbd19ca0&c=254) estimated that 58 percent of American adults responded that they or someone they care for have experienced gun violence in their lifetime.
#
# Gun violence takes an emotional, mental and financial toll on individuals and communities. As per the [report](https://everytownresearch.org/wp-content/uploads/2019/01/Survivor-Research-Report-013119B.pdf), while survivors bear direct costs such as healthcare and lost income, gun violence also hurts local economies by lowering property values, slowing new business creation, and reducing available jobs.
#
# Through this project, our attempt is to understand the enormity of the issue of gun violence in the United States when compared with other [developed nations](http://worldpopulationreview.com/countries/developed-countries/) and to explore the relationship between gun legislation and gun violence.

# %% [markdown]
# ## Our Approach

# %% [markdown]
# Over the years, there has been a steady increase in the number of incidents related to gun violence in the United States. Also, there is an increased number of occurrences of mass shootings observed every year [(Gun Violence Archive)](https://www.gunviolencearchive.org/query/3b48e891-9b20-431f-be82-94179bbda02c). Hence, in order to understand the magnitude of everyday gun violence, we analyzed data on gun violence statistics.
#
# Our observations showed us that:
# <ul>
#     <li>Among developed nations, US leads other countries in gun ownership as well as gun related homicides</li>
#     <li>In the United States, in most of the mass shootings and homicides that involved the use of guns, the weapon was legally obtained</li>
#     <li>However, in US states where atleast one gun-control law was in place, the number of gun related deaths was significantly lower</li>
# </ul>
#
# America is clearly an outlier when it comes to gun violence. There have been multiple researches that suggest that it is in large part due to the easy access Americans have to guns.
#
# We took inspiration from the charts given in the Vox [article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) and attempted to make a data-driven argument using several data visualizations explaining America's unique problem with gun violence.

# %% [markdown]
# ## 1. The United States vs [Other Developed Nations](http://worldpopulationreview.com/countries/developed-countries/)

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/1_CountryAnalysis.png', width = 900)

# %% [markdown]
# The above dashboard supports the claim that the United States is indeed an outlier when it comes to gun violence. From the chart "Homicides by Guns", we can clearly see that the United States has six times as many gun related deaths as Canada, and nearly 16 times as many as Germany. The chart "More Guns Lead to More Gun Deaths", showcases relationship between gun ownership and gun related deaths across developed nations. The United States witnesses the most gun related deaths as well as higher gun ownership. The other two charts compare gun ownership and population statistics of the United States and other developed nations. It indicates that while US accounts for only 33.26% of the total population among all developed nations, it accounts for more than 70% of the total civilian-owned guns.

# %% [markdown]
# **Gun availability is a major risk factor for gun related deaths in developed nations. The above charts eastablish a direct correlation between gun ownership and gun related deaths in the United States.**

# %% [markdown]
# Tableau Public Link:
#
# https://public.tableau.com/profile/prerana7302#!/vizhome/Analysis_of_Gun_Violence_in_United_States/CountryAnalysis

# %% [markdown]
# ## 2. Mass Shootings

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/2_MassShootingsAnalysis.png', width = 900)

# %% [markdown]
# In order to support our claim presented in the previous argument, we analyzed mass shootings that took place between 2013-2019 and whether the weapon used was obtained through legal channels or not. The above visualization showcases the legal status of gun that were used in mass shootings from 2013 to 2019. As more than 70% of the incidents involved the use of a legal weapon, it clearly indicates that most of the mass shooters had easy access to a weapon.

# %% [markdown]
# **Most of the mass shooters obtained weapons legally. The above chart further strengthens our argument that easy accessibility to guns is a major contributing factor towards increasing gun violence in the United States.**

# %% [markdown]
# Tableau Public Link: https://public.tableau.com/profile/prerana7302#!/vizhome/Analysis_of_Gun_Violence_in_United_States/MassShootingsAalysis

# %% [markdown]
# ## 3. Gun Laws and Gun Deaths in United States

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/3_LawAnalysis.png', width = 900)

# %% [markdown]
# Clearly, easy access to guns is leading to more gun deaths in the United States. But, could it be due to lenient gun restriction policies? The first chart in the above dashboard compares the trend in the number of deaths by firearms per 100K people for US states with and without gun restriction policies such as Assault Weapons Ban, Safe Storage or Gun Lock Requirement. It clearly indicates that after 2014, there is a rise in the number of gun deaths for US states where gun restriction policies were not present. We had access to the law implementation data only for the year 2014, so we have used 2014 as a reference year for the analysis. The other two charts compare the difference between the number of gun deaths in states with and without weapon laws for 'Assault Weapons Ban Law' and 'Safe Storage or Gun Lock Law', separately. We can clearly see that the number of people killed are significantly higher for states that implement no laws restricting the use of weapons.

# %% [markdown]
# **Gun deaths are significantly lower for states with stricter gun restriction policies. The above chart indicates a significant difference in the number of gun deaths for states where laws related to Assault Weapons Ban and Safe Storage or Guns Locks exist as compared to the states where these laws do not exist.**

# %% [markdown]
# Tableau Public Link:
# https://public.tableau.com/profile/prerana7302#!/vizhome/Analysis_of_Gun_Violence_in_United_States/LawAnalysis

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We began our analysis by understanding the issue of gun violence across developed nations. We realized that the United States when compared to other developed nations has a very unique problem. It exceeded other developed nations with big margins when it came to both gun ownership by civilians as well as gun-related deaths. We then delved deeper into the problem by exploring mass shootings that have become a frequent occurrence in the United States and also the reasons behind these occurrences. We realized that a major contributing factor was the easy availability of legal guns in the United States. Our intuition was that lenient gun-control laws could be a part of the problem. Hence, we compared the number of deaths by firearms in the US States where gun-control laws were and were not implemented. We found that in states where gun-control laws were implemented, the number of deaths by firearms were declining steadily. Also, there was a significant increase in the number of deaths by firearms over the years where gun-control laws were not implemented.
#
# From this analysis, we conclude that stricter gun-control laws could decrease the frequency of gun-related incidents and also reduce the number of deaths by firearms significantly.

# %% [markdown]
# ---

# %% [markdown]
# # Our Methodology

# %% [markdown]
# We analyzed the issue of gun violence in the United States on multiple levels. We started by analyzing the issue of gun violence across developed nations, where America clearly stands out as an outlier, both in terms of gun ownership and gun related deaths. In order to find the underlying reasons behind the same, we explored historical data on mass shootings and realised that easy accessibility to guns was a major contributing factor to this problem. We delved deeper into the problem by analyzing the number of deaths by firearms for states with and without weapon laws and found that states with no weapon laws observed higher gun related deaths.
#
# Therefore, we can safely conclude that stricter gun-control laws is key in reducing the gun-related incidents and firearm deaths.

# %% [markdown]
# ## 1. United States vs [Other Developed Nations](http://worldpopulationreview.com/countries/developed-countries/)

# %% [markdown]
# There are about 31 countries in the world that qualify as 'Developed' or 'First World' countries, including the United States. Among these nations, the United States is home to about 33.26% of the total population and accounts for roughly [72.72% of the total civilian-owned guns](https://www.theguardian.com/news/datablog/2012/jul/22/gun-homicides-ownership-world-list) alone. On a world level, with less than 5% of the world's population, the United States is home to roughly 35-50% of the world's civilian-owned guns, heavily skewing the global geography of guns and any relative comparison.

# %% [markdown]
# **Graph 1**: This visualization is an enhancement of the chart named "1) America has six times as many firearm homicides as Canada, and nearly 16 times as many as Germany" given in the [Vox](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) article. It indicates the number of gun related homicides per 1 million people for all developed nations. The variables used to plot this graph are Country and homicides per 100K in the world crime dataset. The dataset originally had number of homicides per 100K people. We changed it to homicides per 1 million people for relatability.
# We have highlighed US, Canada and Germany using a different color for a clearer comparision and added an annotation to further support the claim. Also, we sorted and selected top 20 countries by number of homicides to reduce the clutter.

# %% [markdown]
# From this chart we can clearly see that United States is way ahead of other developed nations in terms of gun related homicides and is an <b>outlier on gun violence</b>. Number of homicides by guns per 1 million people in US(29.70) account for <b>almost 6 times that of Canada(5.10) and 16 times that of Germany(1.90)</b>.

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/1_CountrywiseGunHomicides.png')

# %% [markdown]
# **Graph 2**: The below two visualizations compare the difference between the gun ownership and population statistics for the United States and the other developed nations. The variables used to plot this graph are country, population as of 2019 and  average of total number of guns. We created a separate group for all other developed nations except US for a better comparision.
#
# It indicates that while <b>US accounts for only 33.26% of the total population among all developed nations</b>, it is home to <b>more than 70% of the total civilian-owned guns among all the developed nations</b>.

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/1_Population_GunOwnership.png')

# %% [markdown]
# **Graph 3**: This graph is a replication of chart given in [Vox](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) named "6) It’s not just the US: Developed countries with more guns also have more gun deaths". It showcases relationship between gun ownership and gun related deaths across developed nations. The variables used to plot this graph are country, homicides by gun per 100k population and average number of guns per 100K. A trendline is included for all the countries including United States to show the relation between higher gun ownership and homicides by guns.
#
# The chart indicates that <b>US is an outlier when compared to other developed nations. It witnesses more gun related deaths due to higher gun ownership</b>.

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/1_CountrywiseGunsper100vsHomicides.png')

# %% [markdown]
# ### Dashboard 1

# %% [markdown]
# **Gun availability is a major risk factor for homicides in developed nations. This is supported by the dashboard below which indicates that a higher gun ownership in the United States is the reason for higher gun related deaths in the country.**

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/1_CountryAnalysis.png', width = 900)

# %% [markdown]
# Tableau Public Link:
#
# https://public.tableau.com/profile/prerana7302#!/vizhome/Gun_Violence_in_United_States/CountryAnalysis

# %% [markdown]
# ## 2. Mass Shootings

# %% [markdown]
# According to an article in [New York Times](https://www.nytimes.com/2018/12/18/us/gun-deaths.html), "More people died from firearm injuries in the United States in 2017 than in any other year since at least 1968, according to new data from the Centers for Disease Control and Prevention."
#
# In fact, 2017 witnessed the highest number of mass shootings alone, killing and injuring hundreds of innocent lives.

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/2_MassShootings.png', width = 900)

# %% [markdown]
# **Graph 1**: This visualization helps in identifying whether the weapon used in mass shootings was obtained through legal channels or not. The variables used to plot this graph are Weapons Obtained Legally and Number of Mass Shootings.
#
# We can see that <b>more than 70% of the weapons used in the mass shooting incidents were obtained legally.</b>

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/2_MassShootingsAnalysis.png')

# %% [markdown]
# Tableau Public Link:
#
# https://public.tableau.com/profile/prerana7302#!/vizhome/Gun_Violence_in_United_States/MassShootingsAnalysis

# %% [markdown]
# ## 3. Gun Laws and Gun Deaths in United States

# %% [markdown]
# On an average [10 out of every 100,000 people are killed by firearms](https://www.theatlantic.com/national/archive/2011/01/the-geography-of-gun-deaths/69354/) across the United States. And, it is commonly assumed that mental illness or stress levels are few of the major triggers for people commiting such crimes. But in reality, that is not true. This fact is supported by an [article](https://www.theatlantic.com/national/archive/2011/01/the-geography-of-gun-deaths/69354/) which analysed data on a state level and suggests that there is no correlation between gun deaths and any other psychological, economic, social, and political factors. But, they did find a striking correlation between gun deaths and gun control laws. So, can we safely assume that tighter gun control laws make a difference? Some studies indicate that they do.
#
# Therefore, in this section, we are trying to analyze the relation of gun related deaths with gun control restrictions by state. It includes states which have one of three gun control restrictions in place - assault weapons' bans, trigger locks, or safe storage requirements.

# %% [markdown]
# **Graph 1**: This graph shows the death rate trend in the States with and without Weapon Laws (Assault Weapons Ban and Safe Storage or Gun Lock Requirment).
# We can see there is **a rise in average death rate in states with no Weapon Laws while there is a slight dip in average death rate in states where Weapon Laws were implemented.**

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/3_WeaponsBanTrend.png', width = 1000)

# %% [markdown]
# **Graph 2**: This graph indicates the sum of death rate per 100k people and compares that for US states with and without a gun law prohibiting use of weapons qualifying as an 'Assault Weapon'. The variables used are Firearms Death Rate per 100,000 &  Assault Weapons Ban (Indicating presence or absence of the gun law).
#
# We can clearly see that the sum of gun death rate per 100k people is **significantly higher in states that implement no laws restricting use of Assault Weapons.**

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/3_AssaultBanDeaths.png', height = 100)

# %% [markdown]
# **Graph 3**: This graph indicates the sum of death rate per 100k people and compares that for US states with and without safe storage or gun locks laws. Key variables of interest are - Firearms Death Rate per 100,000 & Safe Storage or Gun Lock Requirement.
#
# We can clearly see that the sum of gun death rate per 100k people is **significantly higher in states that implement no laws relating to Safe Storage or Gun Lock Requirement.**

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/3_SafeStorageDeaths.png', height = 100)

# %% [markdown]
# ### Dashboard 3

# %% [markdown]
# **Firearm deaths are significantly lower in states with stricter gun control legislation.  There is a significant difference in the death rate in the states where laws related to Assault Weapons Ban and Safe Storage or Guns Locks exist vs the states where these laws do not exist.**

# %%
Image('https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/Images/Final_Version/3_LawAnalysis.png', width = 900)

# %% [markdown]
# Tableau Public Link:
#
# https://public.tableau.com/profile/prerana7302#!/vizhome/Gun_Violence_in_United_States/LawAnalysis

# %% [markdown]
# ---

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Set Up and Process

# %% [markdown]
# Data cleaning, merging and transformation is done using Python in Jupyter notebook. The final dataset is used in Tableau for visualization.

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 1. United States vs [Other Developed Nations](http://worldpopulationreview.com/countries/developed-countries/)

# %% [markdown]
# ### Datasets and  Sources
# **1. [Gun Homicides and Gun Ownership Data from The Guardian](https://www.theguardian.com/news/datablog/2012/jul/22/gun-homicides-ownership-world-list#data)**: This dataset consists of guns related deaths and ownership details by country. Each row represents a country and details like average guns per 100 people, total guns owned by civilians, etc.
#
# **2. [Developed Countries 2019 Data from World Population Review](http://worldpopulationreview.com/countries/developed-countries/)**: This dataset is a list of developed countries in the world ranked according to their growth rate and population.

# %% [markdown]
# The dataset consists of many variables including Country, ISO code, Source,% of homicides by guns, Number of homicides by firearm, etc. However, our analysis focuses primarily on relationship between gun-related deaths and gun ownership data across developed nations. Therefore, the key variables that we have selected for our analysis are:
#
# **Variables of Interest**
#     <ul>
#       <li>Country: Name of the country </li>
#       <li>% of homicides by guns: Percentage of homicides due to guns</li>
#       <li>Homicide by gun rate per 100,000 pop: Number of homicides happened using guns per 100,000 population</li>
#       <li>Address: Address where the mass shooting incident took place</li>
#       <li>Average total all civilian gun: Average number of guns held by civilians</li>
#       <li>Growth Rate: The rate at which a country is growing according to CIA</li>
#     </ul>

# %% [markdown]
#
# **Limitations**
# - Gun Homicides and Ownership Data is present only for small arms and not for all types of firearms
# - While the website says that the google spreadsheet (Sources: UNODC & Small Arms Survey) displaying this data is updated every 5 mins, we do not know if the statistics for 'Number of homicides' & 'Average guns per 100 people' have been updated for the current years or not
# - Some of the developed nations like United Kingdom and South Korea are not present in Gun Homicides and Gun Ownership Data

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# The dataset needs some processing before we start exploring and visualizing the dataset further.
# - Renaming column names for efficient data handling: This was done for easy understanding of the data during analysis
# - Handling null values: In this step we are removing the null values as they add no value to our analysis and can be ignored
# - Merging with the list of developed countries: This is because the analysis focuses on gun violence statistics across developed nations only

# %% [markdown]
# Step 1: Reading in data for world crimes

# %%
dataset_url = "https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/datasets/"

# %%
world_crime = pd.read_csv(dataset_url + "world_crime.csv")
world_crime.head()
# Out:
#   Country/Territory ISO code               Source  % of homicides by firearm  \
# 0           Albania       AL                  CTS                       65.9
# 1           Algeria       DZ                  CTS                        4.8
# 2            Angola       AO                  NaN                        NaN
# 3          Anguilla       AI              WHO-MDB                       24.0
# 4         Argentina       AR  Ministry of Justice                       52.0
#
#    Number of homicides by firearm  Homicide by firearm rate per 100,000 pop  \
# 0                            56.0                                      1.76
# 1                            20.0                                      0.06
# 2                             NaN                                       NaN
# 3                             1.0                                      7.14
# 4                          1198.0                                      3.02
#
# ...

# %% [markdown]
# Step 2: Renaming columns for efficient data handling

# %%
# Creating a new list of column names
cols = ['Country', 'Country_code', 'Source', '%_homi_gun', 'num_homi_gun', 'homi_gun_per100k', 'rank-rate_owner',\
        'avg_gun_per100', 'avg_tot_all_guns']
# Replacing the existing column names with new names saved in the list 'cols'
world_crime.columns = cols

# %% [markdown]
# Step 3: Handling Null values

# %%
#Checking columns with 'NA' values
world_crime.isna().sum()
# Out:
# Country              0
# Country_code         1
# Source              69
# %_homi_gun          69
# num_homi_gun        69
# homi_gun_per100k    69
# rank-rate_owner      9
# avg_gun_per100       9
# avg_tot_all_guns     9
# dtype: int64

# %%
# Removing all the 'NA' values
world_crime = world_crime.dropna()
len(world_crime)
# Out:
# 107

# %% [markdown]
# Step 4: Merging the crime data will all the countries and combining with a list of developed countries

# %%
# Reading in data for growth rates for all 'Developed' countries
developed_countries = pd.read_csv(dataset_url+"developed.csv")
developed_countries.head()
# Out:
#   cca2            name     area     pop2019  GrowthRate
# 0   US   United States  9372610  329093.110    1.007119
# 1   JP           Japan   377930  126854.745    0.997401
# 2   TR          Turkey   783562   82961.805    1.012756
# 3   DE         Germany   357114   82438.639    1.001764
# 4   GB  United Kingdom   242900   66959.016    1.005791

# %%
# Checking for NAs
developed_countries.isna().sum()
# Out:
# cca2          0
# name          0
# area          0
# pop2019       0
# GrowthRate    0
# dtype: int64

# %% [markdown]
# Step 5: Merging world crime data with growth rate for developed nations in order to find the position of the United States as compared to other countries. We are using inner join because we want to see the data only for developed countries.

# %%
# Merging world crimes and growth rates dataset
world_crime_developed = world_crime.merge(developed_countries, how="inner", left_on="Country", right_on="name")
# Removing columns that are not required for the analysis
world_crime_developed.drop(columns = ['Source', 'cca2','name', 'area'], inplace = True)

# %% [markdown]
# ### Final Dataset

# %%
world_crime_developed.to_csv("world_crime.csv") # writing in csv for visualizations
world_crime_developed.head()
# Out:
#      Country Country_code  %_homi_gun  num_homi_gun  homi_gun_per100k  \
# 0  Australia           AU        11.5          30.0              0.14
# 1    Austria           AT        29.5          18.0              0.22
# 2    Belgium           BE        39.5          70.0              0.68
# 3     Canada           CA        32.0         173.0              0.51
# 4     Cyprus           CY        26.3           5.0              0.46
#
#    rank-rate_owner  avg_gun_per100  avg_tot_all_guns    pop2019  GrowthRate
# 0             42.0            15.0         3050000.0  25088.636    1.012772
# 1             14.0            30.4         2500000.0   8766.201    1.001643
# 2             34.0            17.2         1800000.0  11562.784    1.005589
# 3             13.0            30.8         9950000.0  37279.811    1.008823
# 4              6.0            36.4          275000.0   1198.427    1.007856

# %% [markdown]
# ### Exploration

# %% [markdown]
# Countries as per gun ownership rate

# %%
world_crime_developed.sort_values(by = 'rank-rate_owner')[:5]
# Out:
#           Country Country_code  %_homi_gun  num_homi_gun  homi_gun_per100k  \
# 28  United States           US        60.0        9146.0              2.97
# 26    Switzerland           CH        72.2          57.0              0.77
# 8         Finland           FI        19.8          24.0              0.45
# 4          Cyprus           CY        26.3           5.0              0.46
# 25         Sweden           SE        33.9          37.0              0.41
#
#     rank-rate_owner  avg_gun_per100  avg_tot_all_guns     pop2019  GrowthRate
# 28              1.0            88.8       270000000.0  329093.110    1.007119
# 26              3.0            45.7         3400000.0    8608.259    1.007517
# 8               4.0            45.3         2400000.0    5561.389    1.003405
# 4               6.0            36.4          275000.0    1198.427    1.007856
# 25             10.0            31.6         2800000.0   10053.135    1.007055

# %% [markdown]
# Countries by average number of all civilian owned guns

# %%
world_crime_developed.sort_values(by = 'avg_tot_all_guns', ascending = False)[:5]
# Out:
#           Country Country_code  %_homi_gun  num_homi_gun  homi_gun_per100k  \
# 28  United States           US        60.0        9146.0              2.97
# 10        Germany           DE        26.3         158.0              0.19
# 9          France           FR         9.6          35.0              0.06
# 3          Canada           CA        32.0         173.0              0.51
# 27         Turkey           TR        16.9         535.0              0.77
#
#     rank-rate_owner  avg_gun_per100  avg_tot_all_guns     pop2019  GrowthRate
# 28              1.0            88.8       270000000.0  329093.110    1.007119
# 10             15.0            30.3        25000000.0   82438.639    1.001764
# 9              12.0            31.2        19000000.0   65480.710    1.003793
# 3              13.0            30.8         9950000.0   37279.811    1.008823
# 27             52.0            12.5         9000000.0   82961.805    1.012756

# %% [markdown]
# ## 2. Mass Shootings

# %% [markdown]
# ### Datasets and Sources
#
# **1.  [Mass Shootings Data from Gun Violence Archive](https://www.gunviolencearchive.org/)**: The dataset consists of gun violence incidents collected from Jan 01, 2013 to May 18, 2019. Each row of the dataset represents an incident in the United States with details regarding the incident location and number of people killed and injured.
#
# **2. [City Locations Data from Opensoft](https://public.opendatasoft.com/explore/dataset/1000-largest-us-cities-by-population-with-geographic-coordinates/table/?sort=-rank)**: The dataset consists of US cities and their geographical locations. Each row represents a city and its geographical coordinates and details like population, timezone, etc.
#
# **3. [Details of Mass Shootings from Mother Jones](https://www.motherjones.com/politics/2012/12/mass-shootings-mother-jones-full-data/)**: This dataset consists of details of mass shootings that took place from 1999 till date. Each row represents a mass shooting along with details shooters age, race, gender, weapons obtained legally, number of victims, etc.

# %% [markdown]
# There are many variables in these dataset including incident date, state, city, location, coordinates, population, case, gender, status of the weapon, etc. However, since this analysis focuses on the mass shooting incidents across America and the status of the weapon used in the shooting, we have selected only the key variables such as:
#
# **Variables of Interest:**
# - Incident Date: The date of the mass shooting incident
# - State: State where the mass shooting incident took place
# - City: City where the mass shooting incident took place
# - Address: Address where the mass shooting incident took place
# - num_Killed: Number of people killed in the mass shooting incident
# - num_Injured: Number of people injured in the mass shooting incident
# - Latitude: Latitude of the given city
# - Longitude: Longitude of the given city
# - Weapons obtained legally - Whether the weapon used for mass shooting was obtained legally or not

# %% [markdown]
#
# **Limitations**
# * City Locations Dataset has geolocations only for 1000 largest US cities based on population, so we lose the mass shootings information about some of the smaller cities

# %% [markdown]
# ### Data Cleaning
# This dataset is used for the intial exploration part to get a detailed understanding of the locations where mass shootings are occuring.
# The dataset needs some preparation before we start exploring and visualizing the dataset further. Steps to be follwed are:
# <ul>
#   <li>Renaming columns for efficient data handling: This step is important for better understanding of data during exploration and analysis</li>
#   <li>Creating new features e.g. month and year from date: We created a new time variable for understanding change in the number of deaths over the given time period</li>
#   <li>Adding latitude and longitude (geolocation) for each of the given locations for maps</li>
#   <li>Handling Null values: We removed null values as they add no value to the analysis and can be ignored</li>
# </ul>

# %% [markdown]
#  Sept 1: Reading and merging data for mass shootings from 2013 to 2019

# %%
dataset_url = "https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/datasets/"

# %%
y2013 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2013.csv")
y2014 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2014.csv")
y2015 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2015.csv")
y2016 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2016.csv")
y2017 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2017.csv")
y2018 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2018.csv")
y2019 = pd.read_csv(dataset_url+"Mass%20Shootings%20year%20wise/Mass_Shootings_2019.csv")
# combining data for all the years 
mass_shoot = pd.concat([y2013, y2014, y2015, y2016, y2017, y2018, y2019])
mass_shoot.head()
# Out:
#        Incident Date       State City Or County                     Address  \
# 0  December 31, 2013    New York       Brooklyn             60 Glenmore Ave
# 1  December 28, 2013     Alabama     Montgomery            954 Highland Ave
# 2  December 26, 2013   Louisiana        Slidell               2144 First St
# 3  December 26, 2013   Louisiana       Lockport                313 Tenth St
# 4  December 25, 2013  New Jersey      Irvington  Nye Avenue and 21st Street
#
#    # Killed  # Injured  Operations
# 0       0.0        6.0         NaN
# 1       3.0        5.0         NaN
# 2       2.0        6.0         NaN
# 3       3.0        3.0         NaN
# 4       3.0        2.0         NaN

# %% [markdown]
# Step 2: Renaming columns for efficient data handling

# %%
mass_shoot.rename(columns={'Incident Date':'Date','City Or County':'City', '# Killed':'num_Killed', '# Injured':'num_Injured'}, inplace=True)

# %% [markdown]
# Step 3: Extracting Month and Year from the incident Date column

# %%
from datetime import datetime as dt
mass_shoot['Date']=pd.to_datetime(mass_shoot['Date'])
mass_shoot['Month'] = mass_shoot['Date'].dt.month
mass_shoot['Year'] = mass_shoot['Date'].dt.year

# %% [markdown]
# Step 4: Reading data for Latitudes and Longitudes for cities in the United States for plotting maps

# %%
cities_location = pd.read_csv(dataset_url+ "uscitiesv1.5.csv")
# Selecting relevant columns for further analysis
cities_location_sub = cities_location[['city','state_id', 'state_name','lat', 'lng']]
cities_location_sub.head()
# Out:
#              city state_id  state_name      lat       lng
# 0   Prairie Ridge       WA  Washington  47.1443 -122.1408
# 1          Edison       WA  Washington  48.5602 -122.4311
# 2        Packwood       WA  Washington  46.6085 -121.6702
# 3  Wautauga Beach       WA  Washington  47.5862 -122.5482
# 4          Harper       WA  Washington  47.5207 -122.5196

# %% [markdown]
# Step 5: Merging mass shootings data with city locations to use with maps. Left join has been used to ensure we have all the data from mass_shoot.

# %%
# Merging datasets
mass_shooting_data = mass_shoot.merge(cities_location_sub,how='left', left_on=['City', 'State'], right_on=['city', 'state_name'])
# Dropping extra columns which we won't be using further
mass_shooting_data.drop(columns=['Operations', 'city', 'state_name','state_id'], inplace=True)

# %% [markdown]
# Step 6: Removing all the NA values

# %%
#Removing NA
mass_shooting_data = mass_shooting_data.dropna()
# Checking number of rows in the combined dataframe
len(mass_shooting_data)
# Out:
# 1915

# %% [markdown]
# Weapons Obtained Legally Dataset is used for our final analysis as this contains more information about the weapons obtained legally, age, gender and race. This can help us analyse the demographics of the shooters and visualize whether weapons used are legal or not

# %%
weapons=pd.read_csv("https://raw.githubusercontent.com/pragyansharma24/Gun-Violence-in-United-States/master/datasets/MASS1999.csv")
weapons.head(2)
# Out:
#                                  case           location     date  \
# 0  Harry Pratt Co. warehouse shooting         Aurora, IL  2/15/19
# 1     Pennsylvania hotel bar shooting  State College, PA  1/24/19
#
#                                              summary  fatalities  injured  \
# 0  Gary Martin, 45, went on a rampage inside the ...           5        6
# 1  Jordan Witmer, 21, shot three people at a Rama...           3        1
#
#    total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 0             11  Workplace              45                              Yes
# 1              4      Other              21                                -
#
#    ...                                     weapon_details   race gender  \
# 0  ...  Smith & Wesson handgun, with a green sighting ...  Black      M
# 1  ...                                                  -  White      M
#
#                                              sources mental_health_sources  \
# ...

# %% [markdown]
# ### Final Dataset

# %%
mass_shooting_data.head()
# Out:
#         Date      State        City             Address  num_Killed  \
# 0 2013-12-31   New York    Brooklyn     60 Glenmore Ave         0.0
# 1 2013-12-28    Alabama  Montgomery    954 Highland Ave         3.0
# 2 2013-12-26  Louisiana     Slidell       2144 First St         2.0
# 3 2013-12-26  Louisiana    Lockport        313 Tenth St         3.0
# 5 2013-12-25   New York     Medford  33A Cedarhurst Ave         1.0
#
#    num_Injured  Month    Year      lat      lng
# 0          6.0   12.0  2013.0  40.6501 -73.9496
# 1          5.0   12.0  2013.0  32.3470 -86.2663
# 2          6.0   12.0  2013.0  30.2882 -89.7826
# 3          3.0   12.0  2013.0  29.6418 -90.5376
# 5          3.0   12.0  2013.0  40.8220 -72.9859

# %%
mass_shooting_data.to_csv("mass_shootings.csv")

# %% [markdown]
# ### Exploration

# %% [markdown]
# Cities that lost most number of lives in mass shootings

# %%
mass_shooting_data.groupby('City')['num_Killed','num_Injured'].sum()\
.reset_index().sort_values(by= 'num_Killed', ascending = False)[:5]
# Out:
#             City  num_Killed  num_Injured
# 106      Chicago        82.0        573.0
# 285    Las Vegas        72.0        488.0
# 389      Orlando        68.0        102.0
# 243      Houston        47.0        102.0
# 466  Saint Louis        37.0        148.0

# %%
mass_shooting_data.groupby('State')['num_Killed','num_Injured'].agg(['sum','count','mean','max']).head(10)
# Out:
#                      num_Killed                       num_Injured        \
#                             sum count      mean   max         sum count
# State
# Alabama                    46.0    46  1.000000   5.0       183.0    46
# Alaska                      0.0     1  0.000000   0.0         6.0     1
# Arizona                    47.0    27  1.740741   5.0        89.0    27
# Arkansas                   20.0    18  1.111111   4.0        91.0    18
# California                236.0   223  1.058296  16.0       900.0   223
# Colorado                   23.0    21  1.095238   3.0        76.0    21
# Connecticut                 5.0    14  0.357143   2.0        72.0    14
# Delaware                    9.0    10  0.900000   5.0        38.0    10
# District of Columbia        8.0    30  0.266667   2.0       136.0    30
# Florida                   200.0   129  1.550388  50.0       558.0   129
#
#
#                           mean   max
# State
# Alabama               3.978261  12.0
# ...

# %% [markdown]
# Number of lives lost in mass shootings by year

# %%
mass_shooting_data.groupby('Year')['num_Killed'].sum()\
.reset_index().sort_values(by= 'num_Killed', ascending = False)
# Out:
#      Year  num_Killed
# 3  2016.0       411.0
# 4  2017.0       392.0
# 2  2015.0       332.0
# 5  2018.0       328.0
# 0  2013.0       249.0
# 1  2014.0       242.0
# 6  2019.0       130.0

# %% [markdown]
# ## 3. Gun Laws and Gun Deaths in United States

# %% [markdown]
# ### Datasets and Sources
# **1. [Firearms Law from  Kaiser Family Foundation](https://www.kff.org/other/state-indicator/firearms-and-children-legislation/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)**: This dataset provides information about presence of weapon laws ('Child Access Prevention Firearm Law', 'Safe Storage Gun Lock Requirment Law' or 'Assault Weapons Ban Law') for each of the US states.
#
# **2. [Firearms Deaths from  Kaiser Family Foundation](https://www.kff.org/other/state-indicator/firearms-death-rate-per-100000/?currentTimeframe=3&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)**: This dataset consists number of deaths due to injury by firearms per 100,000 population in each state, defined as 'Firearm Death Rate per 100,000 Population'.
#
# **Variables of Interest:**
#     <ul>
#       <li>State: State in which the incident occured
#       <li>Firearm Child Protection: State laws in place designed to prevent children from accessing firearms </li>
#       <li>Safe Storage or Gun Lock Requirment: State laws concerning firearms locking devices in place</li>
#       <li>Assault Weapons Ban: State law banning assault weapons, by name, or by specific features of the gun that make a gun an assault weapon in place or not</li>
#       <li>Firearms Death Rate per 100,000: Death rate due to injury by firearms per 100,000 population</li>
#     </ul>
#
# **Limitations**
#  *  Firearms Laws dataset is only present for 2014 so the analysis is based on laws present only in 2014. Some states might have changed laws which could not be captured
#  * State laws applies to assault pistols only
#  * Deaths from injury due to firearms excludes deaths due to explosives and other causes indirectly caused by firearms.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# The dataset needs some processing before we start exploring and visualizing the dataset further. Steps to be followed are:
# - Merging 'Firearms Deaths' data with 'Firearm Child Protection': We merged these two datasets to analyze occurences of death across states in America
# - Creating new columns for states which have at least one gun law present and states which have both Assault Weapons Ban and Safe Storage or Gun Lock Requirment present: We created a dummy column for better data handling during analysis

# %% [markdown]
# Step 1: Reading  the datset for firearms and child protection

# %%
firearm_law = pd.read_csv(dataset_url + 'firearm_law.csv', skiprows = 2)

# %% [markdown]
# Step 2: Removing columns and rows that are not required for the analysis

# %%
firearm_law= firearm_law[~(firearm_law.Location == 'United States')]
firearm_law.drop(columns=['Footnotes'], inplace = True)

# %% [markdown]
# Step 3: Creating a new column At least One Law which has any of the laws implemented Child Access Prevention Firearm Law, Safe Storage or Gun Lock Requirment or Assault Weapons Ban

# %%
firearm_law['At least One Law']=((firearm_law['Child Access Prevention Firearm Law']=='Yes')|
                                                    (firearm_law['Safe Storage or Gun Lock Requirment']=='Yes')|
                                                    (firearm_law['Assault Weapons Ban']=='Yes'))*1

# %%
firearm_law['Weapon Laws']=((firearm_law['Safe Storage or Gun Lock Requirment']=='Yes')&
                            (firearm_law['Assault Weapons Ban']=='Yes'))*1
firearm_law['Weapon Laws'].replace({1:'Yes',0:'No'},inplace=True)

# %% [markdown]
# Step 3: Reading  the data for firearms death rate per year and combining into a datafile. Writing the data into a file.

# %%
#import pandas as pd
#import glob
#path = 'Firearm_Death_Rate'
#all_files = glob.glob(path + "/*.csv")
#li = []
#year = 1999
#for filename in all_files:
#    year_data = pd.read_csv(filename,skiprows =2 , index_col=None, header=0)[2:52]
#    year_data['Year'] = year
#    li.append(year_data)
#    year = year+1
#firearms_death_rate = pd.concat(li, axis=0, ignore_index=True)
#firearms_death_rate.to_csv('firearm_deathrate_1999to2017.csv')

# %% [markdown]
# Step 5: Reading  the dataset for firearms death rate

# %%
firearms_death_rate = pd.read_csv(dataset_url + 'firearm_deathrate_1999to2017.csv')
firearms_death_rate= firearms_death_rate[['Location','Firearms Death Rate per 100,000','Year']]

# %% [markdown]
# Step 6: Merging firearms child protection with firearms death data using inner join on state as we need information from both the datasets for our analysis

# %%
firearm_statelaws_deathrate = firearms_death_rate.merge(firearm_law, how="inner", left_on="Location", right_on="Location")

# %% [markdown]
# ### Final Dataset

# %%
firearm_statelaws_deathrate.to_csv('firearm_statelaws_deathrate.csv')
firearm_statelaws_deathrate.head()
# Out:
#   Location  Firearms Death Rate per 100,000  Year  \
# 0   Alaska                             15.8  1999
# 1   Alaska                             17.9  2000
# 2   Alaska                             14.9  2001
# 3   Alaska                             19.9  2002
# 4   Alaska                             19.5  2003
#
#   Child Access Prevention Firearm Law Safe Storage or Gun Lock Requirment  \
# 0                                  No                                  No
# 1                                  No                                  No
# 2                                  No                                  No
# 3                                  No                                  No
# 4                                  No                                  No
#
#   Assault Weapons Ban  At least One Law Weapon Laws
# 0                  No                 0          No
# 1                  No                 0          No
# 2                  No                 0          No
# ...

# %% [markdown]
# ### Exploration

# %% [markdown]
# Average death rate related to firearms when the gun laws are present vs not present

# %%
firearm_statelaws_deathrate.groupby('Child Access Prevention Firearm Law')['Firearms Death Rate per 100,000'].agg(['mean'])
firearm_statelaws_deathrate.groupby('Safe Storage or Gun Lock Requirment')['Firearms Death Rate per 100,000'].agg(['mean'])
firearm_statelaws_deathrate.groupby('Assault Weapons Ban')['Firearms Death Rate per 100,000'].agg(['mean'])
firearm_statelaws_deathrate.groupby('At least One Law')['Firearms Death Rate per 100,000'].agg(['mean'])
# Out:
#                                           mean
# Child Access Prevention Firearm Law
# No                                   12.377990
# Yes                                  10.475564
#                                           mean
# Safe Storage or Gun Lock Requirment
# No                                   12.365857
# Yes                                   7.578469
#                           mean
# Assault Weapons Ban
# No                   12.040602
# Yes                   7.490789
#                        mean
# At least One Law
# 0                 13.088012
# 1                 10.313980

# %% [markdown]
# # Final Thoughts

# %% [markdown]
# The replication of charts by Vox was easy using Tableau but the finding the public sources for the datasets that we needed for the analysis was a challenge.
# For creating the visualization we used Tableau. All the above visuals can be found [here](tableau public link. For cleaning and merging the datasets, we used jupyter notebook so the code can be replicated.

# %% [markdown]
# ## References
#
# * Developed Countries 2019
# http://worldpopulationreview.com/countries/developed-countries/
# * World Population 2019
# http://worldpopulationreview.com/continents/world-population/
# * America’s unique gun violence problem, explained in 17 maps and charts
# https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts
#
# * Gun homicides and gun ownership listed by country
# https://www.theguardian.com/news/datablog/2012/jul/22/gun-homicides-ownership-world-list#data
#
# * Gun Violence Archive (GVA)
# https://www.gunviolencearchive.org/
#
# * 1000 Largest US Cities By Population With Geographic Coordinates
# https://public.opendatasoft.com/explore/dataset/1000-largest-us-cities-by-population-with-geographic-coordinates/table/?sort=-rank
#
# * US Mass Shootings, 1982-2019: Data From Mother Jones’ Investigation
# https://www.motherjones.com/politics/2012/12/mass-shootings-mother-jones-full-data/
#
# * Harvard Injury Control Research Center
# https://www.hsph.harvard.edu/hicrc/firearms-research/guns-and-death/
#
# * States with Firearm Laws Designed to Protect Children
# https://www.kff.org/other/state-indicator/firearms-and-children-legislation/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D
#
# * Number of Deaths Due to Injury by Firearms per 100,000 Population
# https://www.kff.org/other/state-indicator/firearms-death-rate-per-100000/?currentTimeframe=3&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D
#
# * Nearly 40,000 People Died From Guns in U.S. Last Year, Highest in 50 Years
# https://www.nytimes.com/2018/12/18/us/gun-deaths.html
#
# * The Geography of Gun Deaths https://www.theatlantic.com/national/archive/2011/01/the-geography-of-gun-deaths/69354/
#
# * A nation of Survivors https://everytownresearch.org/wp-content/uploads/2019/01/Survivor-Research-Report-013119B.pdf
